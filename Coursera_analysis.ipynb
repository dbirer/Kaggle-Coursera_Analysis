# %% [markdown]
# # Coursera Course Dataset Analysis

# %% [markdown]
# First we should import libraries for EDA.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("coursera_data.csv")
df.head()
# Out:
#    Unnamed: 0                                       course_title  \
# 0         134  (ISC)² Systems Security Certified Practitioner...
# 1         743  A Crash Course in Causality:  Inferring Causal...
# 2         874                     A Crash Course in Data Science
# 3         413                            A Law Student's Toolkit
# 4         635                A Life of Happiness and Fulfillment
#
#           course_organization course_Certificate_type  course_rating  \
# 0                      (ISC)²          SPECIALIZATION            4.7
# 1  University of Pennsylvania                  COURSE            4.7
# 2    Johns Hopkins University                  COURSE            4.5
# 3             Yale University                  COURSE            4.7
# 4   Indian School of Business                  COURSE            4.8
#
#   course_difficulty course_students_enrolled
# 0          Beginner                     5.3k
# 1      Intermediate                      17k
# 2             Mixed                     130k
# 3             Mixed                      91k
# 4             Mixed                     320k

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
# Unnamed: 0                  891 non-null int64
# course_title                891 non-null object
# course_organization         891 non-null object
# course_Certificate_type     891 non-null object
# course_rating               891 non-null float64
# course_difficulty           891 non-null object
# course_students_enrolled    891 non-null object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 48.8+ KB

# %%
df=df.drop(df.columns[0],axis=1) #Unnamed:0 column doesn't comes meaningful.

# %%
df.columns=df.columns.str.replace("_"," ")
df.columns=df.columns.str.capitalize()

# %%
df.head() #Now its look better
# Out:
#                                         Course title  \
# 0  (ISC)² Systems Security Certified Practitioner...
# 1  A Crash Course in Causality:  Inferring Causal...
# 2                     A Crash Course in Data Science
# 3                            A Law Student's Toolkit
# 4                A Life of Happiness and Fulfillment
#
#           Course organization Course certificate type  Course rating  \
# 0                      (ISC)²          SPECIALIZATION            4.7
# 1  University of Pennsylvania                  COURSE            4.7
# 2    Johns Hopkins University                  COURSE            4.5
# 3             Yale University                  COURSE            4.7
# 4   Indian School of Business                  COURSE            4.8
#
#   Course difficulty Course students enrolled
# 0          Beginner                     5.3k
# 1      Intermediate                      17k
# 2             Mixed                     130k
# 3             Mixed                      91k
# 4             Mixed                     320k

# %%
len(df) #That shows us number of rows(instances)
# Out:
# 891

# %%
df["Course difficulty"].value_counts()
# Out:
# Beginner        487
# Intermediate    198
# Mixed           187
# Advanced         19
# Name: Course difficulty, dtype: int64

# %%
sns.countplot(x="Course difficulty",data=df);

# %%
df.sort_values(by="Course rating",ascending=False)
# Out:
#                                           Course title  \
# 251  El Abogado del Futuro: Legaltech y la Transfor...
# 432                       Infectious Disease Modelling
# 754                               Stories of Infection
# 290      Everyday Parenting: The ABCs of Child Rearing
# 98                  Boosting Creativity for Innovation
# 99   Brand Management: Aligning Business, Brand and...
# 614          More Introduction to Financial Accounting
# 102                Bugs 101: Insect-Human Interactions
# 836  Understanding Einstein: The Special Theory of ...
# 103  Build a Modern Computer from First Principles:...
# 291                          Excel Skills for Business
# 512                         Introduction to Psychology
# 842  Understanding the Brain: The Neurobiology of E...
# 250                           Egiptología (Egyptology)
# 249                      Effective Compliance Programs
# 247                     Economics of Money and Banking
# 846                        Unraveling the Cycling City
# 618                         Music Business Foundations
# 61   Aprendiendo a aprender: Poderosas herramientas...
# 147  Compassionate Leadership Through Service Learn...
# 40                             American Contract Law I
# 615                                      Mountains 101
# 815                          The Science of Well-Being
# 82   Become a CBRS Certified Professional Installer...
# 556                            Learn to Speak Korean 1
# 807      The Oral Cavity: Portal to Health and Disease
# 564                                   Machine Learning
# 743  Soporte de Tecnologías de la Información de Go...
# 162                      Convolutional Neural Networks
# 626                  Neural Networks and Deep Learning
# ..                                                 ...
# 548                                      Learn English
# 480   Introduction to Computer Science and Programming
# 13          AWS Fundamentals: Addressing Security Risk
# 826             Trading Strategies in Emerging Markets
# 592                Mastering Software Development in R
# 107  Building Scalable Java Microservices with Spri...
# 774               Survey Data Collection and Analytics
# 755                       Strategic Business Analytics
# 601    Memoir and Personal Essay: Write About Yourself
# 153                                Conflict Management
# 172                           Creative Problem Solving
# 856                                    Virtual Teacher
# 693                                Recommender Systems
# 590                   Mastering Data Analysis in Excel
# 59                      Aprende a programar con Python
# 182                  Cybersecurity and Its Ten Domains
# 844              Unity XR: How to Build AR and VR Apps
# 402     Hardware Description Languages for FPGA Design
# 515            Introduction to Spreadsheets and Models
# 676                                  Project Execution
# 640                                Optical Engineering
# 331                 Foundations of Marketing Analytics
# 445  Instructional Design Foundations and Applications
# 414                     How to Start Your Own Business
# 522    Introduction to Trading, Machine Learning & GCP
# 598              Mathematics for Machine Learning: PCA
# 873                     iOS App Development with Swift
# 569                       Machine Learning for Trading
# 566  Machine Learning and Reinforcement Learning in...
# 413  How To Create a Website in a Weekend! (Project...
#
#                             Course organization   Course certificate type  \
# 251                         Universidad Austral                    COURSE
# 432                     Imperial College London            SPECIALIZATION
# 754                         Stanford University                    COURSE
# 290                             Yale University                    COURSE
# 98                                    HEC Paris                    COURSE
# 99                       London Business School                    COURSE
# 614                  University of Pennsylvania                    COURSE
# 102                       University of Alberta                    COURSE
# 836                         Stanford University                    COURSE
# 103              Hebrew University of Jerusalem                    COURSE
# 291                        Macquarie University            SPECIALIZATION
# 512                             Yale University                    COURSE
# 842                   The University of Chicago                    COURSE
# 250           Universitat Autònoma de Barcelona                    COURSE
# 249                  University of Pennsylvania                    COURSE
# 247                         Columbia University                    COURSE
# 846                     University of Amsterdam                    COURSE
# 618                    Berklee College of Music                    COURSE
# 61           University of California San Diego                    COURSE
# 147              University of Colorado Boulder                    COURSE
# 40                              Yale University                    COURSE
# 615                       University of Alberta                    COURSE
# 815                             Yale University                    COURSE
# 82                    Google - Spectrum Sharing                    COURSE
# 556                           Yonsei University                    COURSE
# 807                  University of Pennsylvania                    COURSE
# 564                         Stanford University                    COURSE
# 743                            Crece con Google  PROFESSIONAL CERTIFICATE
# 162                             deeplearning.ai                    COURSE
# 626                             deeplearning.ai                    COURSE
# ..                                          ...                       ...
# 548                         Tsinghua University            SPECIALIZATION
# 480            Goldsmiths, University of London            SPECIALIZATION
# 13                          Amazon Web Services                    COURSE
# 826                   Indian School of Business            SPECIALIZATION
# 592                    Johns Hopkins University            SPECIALIZATION
# 107                                Google Cloud                    COURSE
# 774        University of Maryland, College Park            SPECIALIZATION
# 755                       ESSEC Business School            SPECIALIZATION
# 601                         Wesleyan University            SPECIALIZATION
# 153            University of California, Irvine            SPECIALIZATION
# 172                     University of Minnesota                    COURSE
# 856            University of California, Irvine            SPECIALIZATION
# 693                     University of Minnesota            SPECIALIZATION
# 590                             Duke University                    COURSE
# 59                          Universidad Austral            SPECIALIZATION
# 182                University System of Georgia                    COURSE
# 844                                       Unity            SPECIALIZATION
# 402              University of Colorado Boulder                    COURSE
# 515                  University of Pennsylvania                    COURSE
# 676            University of California, Irvine                    COURSE
# 640              University of Colorado Boulder            SPECIALIZATION
# 331                            Emory University            SPECIALIZATION
# 445  University of Illinois at Urbana-Champaign                    COURSE
# 414                   Michigan State University            SPECIALIZATION
# 522               New York Institute of Finance                    COURSE
# 598                     Imperial College London                    COURSE
# 873                       University of Toronto            SPECIALIZATION
# 569                                Google Cloud            SPECIALIZATION
# 566                         New York University            SPECIALIZATION
# 413            The State University of New York                    COURSE
#
#      Course rating Course difficulty Course students enrolled
# 251            5.0          Beginner                     1.5k
# 432            5.0      Intermediate                     1.6k
# 754            4.9      Intermediate                      28k
# 290            4.9          Beginner                      86k
# 98             4.9          Beginner                     9.5k
# 99             4.9          Beginner                      57k
# 614            4.9             Mixed                      40k
# 102            4.9          Beginner                      15k
# 836            4.9          Beginner                      89k
# 103            4.9             Mixed                      95k
# 291            4.9          Beginner                     240k
# 512            4.9          Beginner                     270k
# 842            4.9          Beginner                     130k
# 250            4.9          Beginner                      46k
# 249            4.9             Mixed                     3.4k
# 247            4.9             Mixed                      83k
# 846            4.9      Intermediate                     3.9k
# 618            4.9             Mixed                      34k
# 61             4.9          Beginner                     180k
# 147            4.9          Beginner                     6.4k
# 40             4.9          Beginner                      18k
# 615            4.9             Mixed                      44k
# 815            4.9             Mixed                     2.5m
# 82             4.9             Mixed                     210k
# 556            4.9          Beginner                     120k
# 807            4.9      Intermediate                     9.4k
# 564            4.9             Mixed                     3.2m
# 743            4.9          Beginner                     8.8k
# 162            4.9      Intermediate                     240k
# 626            4.9      Intermediate                     630k
# ..             ...               ...                      ...
# 548            4.3          Beginner                      22k
# 480            4.3          Beginner                      32k
# 13             4.3          Beginner                      11k
# 826            4.3          Beginner                      68k
# 592            4.3          Beginner                      52k
# 107            4.3      Intermediate                      24k
# 774            4.3          Beginner                      45k
# 755            4.3          Advanced                      60k
# 601            4.3          Beginner                      13k
# 153            4.3          Beginner                      66k
# 172            4.3             Mixed                     140k
# 856            4.3          Beginner                      23k
# 693            4.3      Intermediate                      29k
# 590            4.2             Mixed                     280k
# 59             4.2          Beginner                     6.6k
# 182            4.2          Beginner                     140k
# 844            4.2          Beginner                      12k
# 402            4.2      Intermediate                     7.4k
# 515            4.2             Mixed                      76k
# 676            4.2          Beginner                      70k
# 640            4.2          Advanced                     6.2k
# 331            4.2      Intermediate                      27k
# 445            4.2             Mixed                      12k
# 414            4.1          Beginner                      34k
# 522            4.0      Intermediate                      13k
# 598            4.0      Intermediate                      33k
# 873            3.9      Intermediate                      76k
# 569            3.9      Intermediate                      15k
# 566            3.7      Intermediate                      29k
# 413            3.3             Mixed                     140k
#
# [891 rows x 6 columns]

# %%
df.groupby("Course organization")["Course rating"].mean()
# Out:
# Course organization
# (ISC)²                                          4.733333
# Amazon Web Services                             4.550000
# American Institute of Business and Economics    4.400000
# American Museum of Natural History              4.750000
# Arizona State University                        4.771429
# Atlassian                                       4.750000
# Autodesk                                        4.750000
# Automation Anywhere                             4.600000
# BCG                                             4.800000
# Berklee College of Music                        4.807143
# Birkbeck, University of London                  4.600000
# Bloomsbury Learning Exchange                    4.700000
# California Institute of the Arts                4.716667
# Case Western Reserve University                 4.733333
# Cisco                                           4.700000
# Cloudera                                        4.800000
# Columbia University                             4.757143
# ConsenSys Academy                               4.700000
# Copenhagen Business School                      4.680000
# Crece con Google                                4.900000
# Duke University                                 4.664286
# E-Learning Development Fund                     4.733333
# EDHEC Business School                           4.666667
# ESADE Business and Law School                   4.800000
# ESCP Business School                            4.600000
# ESSEC Business School                           4.600000
# Eindhoven University of Technology              4.800000
# Emory University                                4.500000
# Erasmus University Rotterdam                    4.660000
# Fundação Instituto de Administração             4.500000
#                                                   ...
# University of California, Santa Cruz            4.725000
# University of Cape Town                         4.700000
# University of Colorado Boulder                  4.668421
# University of Colorado System                   4.715385
# University of Copenhagen                        4.700000
# University of Florida                           4.800000
# University of Geneva                            4.733333
# University of Illinois at Urbana-Champaign      4.654545
# University of Lausanne                          4.800000
# University of London                            4.566667
# University of Maryland, College Park            4.583333
# University of Michigan                          4.729268
# University of Minnesota                         4.609091
# University of New Mexico                        4.600000
# University of Pennsylvania                      4.696610
# University of Pittsburgh                        4.733333
# University of Toronto                           4.627273
# University of Virginia                          4.715789
# University of Washington                        4.660000
# Università Bocconi                              4.757143
# VMware                                          4.800000
# Vanderbilt University                           4.666667
# Wesleyan University                             4.540000
# West Virginia University                        4.550000
# Yale University                                 4.817647
# Yonsei University                               4.750000
# deeplearning.ai                                 4.743750
# École Polytechnique                             4.800000
# École Polytechnique Fédérale de Lausanne        4.725000
# École des Ponts ParisTech                       4.700000
# Name: Course rating, Length: 154, dtype: float64

# %%
def course_number(org):
    "This function is returns you number of course of university you asked."
    number=len(df[df["Course organization"]==org])
    return number

# %%
course_number("Copenhagen Business School")
# Out:
# 5

# %%
df["Course certificate type"].value_counts()
# Out:
# COURSE                      582
# SPECIALIZATION              297
# PROFESSIONAL CERTIFICATE     12
# Name: Course certificate type, dtype: int64

# %%
sns.countplot(x="Course certificate type",data=df);

# %%
sns.boxplot(x="Course certificate type",y="Course rating",data=df);

# %%
diffs=list(df["Course difficulty"].unique())
diffsr=list(df["Course difficulty"].value_counts().values)

# %%
plt.pie(x=diffsr,labels=diffs,autopct="%.1f",startangle=180,explode=[0.01,0.01,0.01,0.01]);
plt.show()
